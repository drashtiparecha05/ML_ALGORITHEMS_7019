# %% [markdown]
# # kFold

# %%
# ⚙️ Setup — Run this first!
# !git clone https://github.com/kaushikajani3002-rgb/ML-Implementations.git 2>/dev/null || True
import os; os.chdir('/content/ML-Implementations')
# !pip install scikit-learn pandas numpy matplotlib seaborn mlxtend -q
print('✅ Ready!')

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LogisticRegression

iris = load_iris()
print("Iris labels:", iris.target)

logreg = LogisticRegression()

kfold = KFold(n_splits=3)
print("CV scores (no shuffle):", cross_val_score(logreg, iris.data, iris.target, cv=kfold))

kfold = KFold(n_splits=3, shuffle=True, random_state=0)
print("CV scores (shuffled):", cross_val_score(logreg, iris.data, iris.target, cv=kfold))
